# %%
SYSTEM = ds[0]["messages"][0]["content"]   # eğitimdeki system'ın birebir aynısı

msgs = [
    {"role": "system", "content": SYSTEM},
    {"role": "user", "content": "Ekran: Bildirim tercihleri\nAçıklama: Ses, titreşim ve rahatsız etmeyin anahtarları.\nState: flutter_bloc (Cubit)."},
]
prompt = tok.apply_chat_template(msgs, tokenize=False, add_generation_prompt=True)
inputs = tok(prompt, return_tensors="pt").to(model.device)

model.config.use_cache = True
out = model.generate(**inputs, max_new_tokens=1200, temperature=0.3, do_sample=True)
print(tok.decode(out[0][inputs["input_ids"].shape[1]:], skip_special_tokens=True))
